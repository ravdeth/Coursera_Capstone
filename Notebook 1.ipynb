# %% [markdown]
#  ## Jupyter Notebook using IBM watson studio

# %% [markdown]
# This notebook is created to display some of basics of python in order to get started.

# %% [markdown]
# Import pandas

# %%
import pandas as pd

# %% [markdown]
# Import numpy

# %%
import numpy as np

# %% [markdown]
# Print given sentence

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
